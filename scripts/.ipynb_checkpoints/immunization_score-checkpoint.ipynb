# %%
import pandas as pd
import os
import matplotlib
import matplotlib.pyplot as plt

data = pd.read_csv("python/final_project/data/original_life_expectancy_data.csv")
measles = pd.read_csv("python/final_project/data/measles_immunization.csv")

IMMUNIZATION_COLUMNS = ["Country", "Year", "Life expectancy ", "Hepatitis B", "Diphtheria ", "Polio"]
idata = data[IMMUNIZATION_COLUMNS].copy()
idata.columns = ['country', 'year', 'life_expectancy', 'hep_b', 'diphtheria', 'polio']

idata.fillna(idata.mean())

# for year in range(2000,2016):
year = 2014
measles_year = measles[['Country Name', str(year)]].copy()
measles_year.columns = ['country', 'measles']
idata_year = idata.merge(measles_year, how="left", on="country")

idata_year['immunization_score'] = round((idata_year['hep_b'] + idata_year['diphtheria'] + idata_year['polio'] + idata_year['measles']) / 4, 2)

idata_year.drop(idata[idata_year['year'] != year].index, inplace=True)

idata

plt.scatter(idata_year.life_expectancy, idata_year.immunization_score, color="red")
plt.title("Immunization Score vs Life Expectancy - " + str(year))
plt.xlim([45,90])
plt.xlabel("Life Expectancy At Birth")
plt.ylabel("Immunization Score")
plt.savefig(str(year) + "_fig")
plt.show()

# %%
# idata = data[IMMUNIZATION_COLUMNS].copy()

# %%
# idata.head()

# %%
# idata.columns

# %%
# idata.columns = ['country', 'year', 'life_expectancy', 'hep_b', 'diphtheria', 'polio']

# %%
# idata.fillna(idata.mean())

# %%
# measles = pd.read_csv("python/final_project/data/measles_immunization.csv")
# measles = measles[['Country Name', '2012']].copy()
# measles.columns = ['country', 'measles']
# idata = idata.merge(measles, how="left", on="country")
# measles.head()

# %%
# idata['immunization_score'] = round((idata['hep_b'] + idata['diphtheria'] + idata['polio'] + idata['measles']) / 4, 2)
# idata.head()

# %%
# print(f"Number of countries: {len(idata['country'].unique())}")

# %%
# idata.drop(idata[idata['year'] != 2012].index, inplace=True)
# idata.head()

# %%
# import matplotlib.pyplot as mpl

# mpl.scatter(idata.life_expectancy, idata.immunization_score, color="red")

# %%
# idata.loc[idata.immunization_score < 40]
